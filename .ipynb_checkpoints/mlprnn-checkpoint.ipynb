# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, SimpleRNN, Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Load dataset
file_path = "C:\\Users\\HP\\Downloads\\NEWS.csv"
data = pd.read_csv(file_path)

# Preprocess text data
data['text'] = data['text'].apply(lambda x: x.lower() if pd.notna(x) else "")

# Encode labels
label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data['label'])
num_classes = len(label_encoder.classes_)

# Prepare data for training
x = data['text']
y = to_categorical(data['label'], num_classes=num_classes)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Tokenization
max_words = 10000  
max_sequence_length = 100  
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
x_train_sequences = tokenizer.texts_to_sequences(x_train)
x_test_sequences = tokenizer.texts_to_sequences(x_test)

# Padding sequences
x_train_padded = pad_sequences(x_train_sequences, maxlen=max_sequence_length)
x_test_padded = pad_sequences(x_test_sequences, maxlen=max_sequence_length)

# Define hybrid model
embedding_dim = 100  
RNN_units = 128
MLP_units = 64

def build_hybrid_model():
    model = Sequential()
    model.add(Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length))
    model.add(Bidirectional(SimpleRNN(units=RNN_units, dropout=0.2, recurrent_dropout=0.2)))
    model.add(Dense(MLP_units, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Train model
model = build_hybrid_model()
epochs = 50
batch_size = 32

history = model.fit(x_train_padded, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)

# Evaluate model
y_pred = model.predict(x_test_padded)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision * 100:.2f}%")
print(f"Recall: {recall * 100:.2f}%")
print(f"F1 Score: {f1 * 100:.2f}%")

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))

# Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap='viridis', values_format='d')
plt.title('Confusion Matrix for Hybrid Model')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Plot Training & Validation Accuracy and Loss
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training & Validation Accuracy')

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training & Validation Loss')

plt.show()
# Out:
# Epoch 1/50
# 84/84 [==============================] - 8s 73ms/step - loss: 0.7104 - accuracy: 0.5309 - val_loss: 0.5950 - val_accuracy: 0.8194
# Epoch 2/50
# 84/84 [==============================] - 5s 56ms/step - loss: 0.6472 - accuracy: 0.6133 - val_loss: 0.5900 - val_accuracy: 0.7157
# Epoch 3/50
# 84/84 [==============================] - 5s 58ms/step - loss: 0.6026 - accuracy: 0.6766 - val_loss: 0.5270 - val_accuracy: 0.7860
# Epoch 4/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.5088 - accuracy: 0.7444 - val_loss: 0.3378 - val_accuracy: 0.9431
# Epoch 5/50
# 84/84 [==============================] - 5s 62ms/step - loss: 0.3343 - accuracy: 0.8573 - val_loss: 0.1731 - val_accuracy: 0.9632
# Epoch 6/50
# 84/84 [==============================] - 4s 53ms/step - loss: 0.2464 - accuracy: 0.9013 - val_loss: 0.2616 - val_accuracy: 0.9298
# Epoch 7/50
# 84/84 [==============================] - 6s 71ms/step - loss: 0.1932 - accuracy: 0.9307 - val_loss: 0.0927 - val_accuracy: 0.9699
# Epoch 8/50
# 84/84 [==============================] - 5s 61ms/step - loss: 0.1255 - accuracy: 0.9572 - val_loss: 0.7475 - val_accuracy: 0.8161
# Epoch 9/50
# 84/84 [==============================] - 4s 53ms/step - loss: 0.0870 - accuracy: 0.9743 - val_loss: 0.4639 - val_accuracy: 0.9030
# Epoch 10/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.0895 - accuracy: 0.9747 - val_loss: 0.1226 - val_accuracy: 0.9666
# Epoch 11/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.0757 - accuracy: 0.9754 - val_loss: 0.1057 - val_accuracy: 0.9666
# Epoch 12/50
# 84/84 [==============================] - 4s 50ms/step - loss: 0.0464 - accuracy: 0.9858 - val_loss: 0.1220 - val_accuracy: 0.9766
# Epoch 13/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.0405 - accuracy: 0.9911 - val_loss: 0.1042 - val_accuracy: 0.9766
# Epoch 14/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.0408 - accuracy: 0.9885 - val_loss: 0.1254 - val_accuracy: 0.9766
# Epoch 15/50
# 84/84 [==============================] - 4s 52ms/step - loss: 0.0337 - accuracy: 0.9899 - val_loss: 0.2071 - val_accuracy: 0.9632
# Epoch 16/50
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0306 - accuracy: 0.9907 - val_loss: 0.2572 - val_accuracy: 0.9565
# Epoch 17/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.0484 - accuracy: 0.9866 - val_loss: 0.0784 - val_accuracy: 0.9799
# Epoch 18/50
# 84/84 [==============================] - 6s 67ms/step - loss: 0.0183 - accuracy: 0.9970 - val_loss: 0.1064 - val_accuracy: 0.9833
# Epoch 19/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 0.1910 - val_accuracy: 0.9732
# Epoch 20/50
# 84/84 [==============================] - 5s 62ms/step - loss: 0.0140 - accuracy: 0.9974 - val_loss: 0.2713 - val_accuracy: 0.9565
# Epoch 21/50
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0161 - accuracy: 0.9970 - val_loss: 0.1966 - val_accuracy: 0.9666
# Epoch 22/50
# 84/84 [==============================] - 5s 64ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 0.1964 - val_accuracy: 0.9699
# Epoch 23/50
# 84/84 [==============================] - 5s 63ms/step - loss: 0.0072 - accuracy: 0.9989 - val_loss: 0.1568 - val_accuracy: 0.9799
# Epoch 24/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.1596 - val_accuracy: 0.9465
# Epoch 25/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.0136 - accuracy: 0.9970 - val_loss: 0.1556 - val_accuracy: 0.9732
# Epoch 26/50
# 84/84 [==============================] - 5s 55ms/step - loss: 0.0140 - accuracy: 0.9970 - val_loss: 0.3478 - val_accuracy: 0.9498
# Epoch 27/50
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0114 - accuracy: 0.9970 - val_loss: 0.1398 - val_accuracy: 0.9799
# Epoch 28/50
# 84/84 [==============================] - 5s 65ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.2093 - val_accuracy: 0.9699
# Epoch 29/50
# 84/84 [==============================] - 5s 58ms/step - loss: 0.0072 - accuracy: 0.9985 - val_loss: 0.1645 - val_accuracy: 0.9766
# Epoch 30/50
# 84/84 [==============================] - 6s 73ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.1564 - val_accuracy: 0.9799
# Epoch 31/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.2023 - val_accuracy: 0.9732
# Epoch 32/50
# 84/84 [==============================] - 4s 53ms/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 0.1685 - val_accuracy: 0.9666
# Epoch 33/50
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0104 - accuracy: 0.9981 - val_loss: 0.1281 - val_accuracy: 0.9799
# Epoch 34/50
# 84/84 [==============================] - 5s 64ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.1905 - val_accuracy: 0.9699
# Epoch 35/50
# 84/84 [==============================] - 5s 56ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.2128 - val_accuracy: 0.9732
# Epoch 36/50
# 84/84 [==============================] - 6s 71ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.3266 - val_accuracy: 0.9532
# Epoch 37/50
# 84/84 [==============================] - 5s 64ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.3458 - val_accuracy: 0.9498
# Epoch 38/50
# 84/84 [==============================] - 5s 58ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.1963 - val_accuracy: 0.9732
# Epoch 39/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.0429 - accuracy: 0.9836 - val_loss: 0.1683 - val_accuracy: 0.9599
# Epoch 40/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.2155 - val_accuracy: 0.9732
# Epoch 41/50
# 84/84 [==============================] - 5s 58ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.2784 - val_accuracy: 0.9565
# Epoch 42/50
# 84/84 [==============================] - 6s 72ms/step - loss: 0.0164 - accuracy: 0.9963 - val_loss: 0.3028 - val_accuracy: 0.9632
# Epoch 43/50
# 84/84 [==============================] - 5s 62ms/step - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.3322 - val_accuracy: 0.9565
# Epoch 44/50
# 84/84 [==============================] - 5s 63ms/step - loss: 0.0271 - accuracy: 0.9907 - val_loss: 0.3971 - val_accuracy: 0.9164
# Epoch 45/50
# 84/84 [==============================] - 6s 68ms/step - loss: 0.0198 - accuracy: 0.9952 - val_loss: 0.2079 - val_accuracy: 0.9699
# Epoch 46/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.2395 - val_accuracy: 0.9732
# Epoch 47/50
# 84/84 [==============================] - 5s 57ms/step - loss: 0.0169 - accuracy: 0.9948 - val_loss: 0.1752 - val_accuracy: 0.9532
# Epoch 48/50
# 84/84 [==============================] - 6s 69ms/step - loss: 0.0139 - accuracy: 0.9948 - val_loss: 0.1868 - val_accuracy: 0.9599
# Epoch 49/50
# 84/84 [==============================] - 5s 62ms/step - loss: 0.0261 - accuracy: 0.9933 - val_loss: 0.9227 - val_accuracy: 0.8361
# Epoch 50/50
# 84/84 [==============================] - 6s 66ms/step - loss: 0.0421 - accuracy: 0.9903 - val_loss: 0.2133 - val_accuracy: 0.9599
# 24/24 [==============================] - 1s 8ms/step
# Accuracy: 95.44%
# Precision: 95.44%
# Recall: 95.44%
# F1 Score: 95.44%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         FAKE       0.95      0.96      0.95       373
#         REAL       0.96      0.95      0.95       373
#
#     accuracy                           0.95       746
#    macro avg       0.95      0.95      0.95       746
# weighted avg       0.95      0.95      0.95       746

# %%
# Save the trained model in .h5 format
model.save("hybrid_model.h5")
print("Model saved successfully as 'hybrid_model.h5'")
# Out:
# Model saved successfully as 'hybrid_model.h5'

# %%
import pickle

# Save the tokenizer
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)
print("Tokenizer saved successfully as 'tokenizer.pkl'")
# Out:
# Tokenizer saved successfully as 'tokenizer.pkl'

# %%
# Save the label encoder
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(label_encoder, f)
print("Label encoder saved successfully as 'label_encoder.pkl'")
# Out:
# Label encoder saved successfully as 'label_encoder.pkl'
